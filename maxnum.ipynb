# %% [markdown]
# <a href="https://colab.research.google.com/github/jannyuary/cs1-python-diamond-maratas/blob/main/maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ask the user to input three numbers
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))

# Compare to find the biggest number
max_number = num1
if num2 > max_number:
    max_number = num2
if num3 > max_number:
    max_number = num3

# Print the biggest number
print("The biggest number is:", max_number)
